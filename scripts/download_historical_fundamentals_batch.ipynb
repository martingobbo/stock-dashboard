# %%
# === Cell 1: Planner (no downloads) ===
#!/usr/bin/env python3
"""
Plans the next FMP jobs to run (no API calls), prints a status snapshot and a preview list.
Run this first. It defines PLANNED_JOBS and STATUS_MAP for Cell 2 to consume.
"""

from pathlib import Path
from typing import Dict, List, Tuple
import json
import duckdb

# ---------------- CONFIG (shared across cells) ----------------
API_KEY   = "c5PobUQjaaMTHySILWqmWi9uyIDqYJBi"  # your key
DB_PATH   = "/Users/martingobbo/stock-dashboard/data/serving/analytics.duckdb"
RAW_ROOT  = Path("/Users/martingobbo/stock-dashboard/data/raw/fmp")

SUBDIRS = {
    "income_statement": RAW_ROOT / "income_statement",
    "balance_sheet":    RAW_ROOT / "balance_sheet",
    "cash_flow":        RAW_ROOT / "cash_flow",
    "ratios":           RAW_ROOT / "ratios",
}

BASE = "https://financialmodelingprep.com/api/v3"
# Index-aligned with STATUS_COLS
ENDPOINTS: List[Tuple[str, str, dict]] = [
    ("income_statement",  f"{BASE}/income-statement/{{sym}}",        {"period": "annual",  "limit": "60"}),  # inc_FY
    ("income_statement",  f"{BASE}/income-statement/{{sym}}",        {"period": "quarter", "limit": "40"}),  # inc_Q
    ("balance_sheet",     f"{BASE}/balance-sheet-statement/{{sym}}", {"period": "annual",  "limit": "60"}),  # bs_FY
    ("balance_sheet",     f"{BASE}/balance-sheet-statement/{{sym}}", {"period": "quarter", "limit": "40"}),  # bs_Q
    ("cash_flow",         f"{BASE}/cash-flow-statement/{{sym}}",     {"period": "annual",  "limit": "60"}),  # cf_FY
    ("cash_flow",         f"{BASE}/cash-flow-statement/{{sym}}",     {"period": "quarter", "limit": "40"}),  # cf_Q
    ("ratios",            f"{BASE}/ratios/{{sym}}",                  {"limit": "60"}),                       # ratios
]
STATUS_COLS = ["inc_FY", "inc_Q", "bs_FY", "bs_Q", "cf_FY", "cf_Q", "ratios"]

# Tweakable display knobs for planning
STATUS_LIMIT = 40   # show first N tickers in the status table
PREVIEW      = 30   # show first N planned jobs

# ---------------- Helpers (shared with Cell 2) ----------------
def ensure_dirs():
    for p in SUBDIRS.values():
        p.mkdir(parents=True, exist_ok=True)

def get_all_tickers_from_duckdb() -> List[str]:
    con = duckdb.connect(DB_PATH, read_only=True)
    rows = con.execute("SELECT ticker FROM dim_ticker ORDER BY ticker;").fetchall()
    return [r[0] for r in rows]

def file_has_any_rows(path: Path) -> bool:
    if not path.exists():
        return False
    try:
        with path.open("r") as f:
            for _ in f:
                return True
    except Exception:
        return False
    return False

def jsonl_has_period(path: Path, want_period: str) -> bool:
    """
    want_period 'annual' -> accepts 'FY'/'annual'/'year' (case-insensitive)
    want_period 'quarter' -> accepts 'quarter' or strings starting with 'Q' (Q1..Q4)
    """
    if not path.exists():
        return False
    annual_tags = {"fy", "annual", "year"}
    try:
        with path.open("r") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    obj = json.loads(line)
                except Exception:
                    continue
                p = str(obj.get("period", "")).strip().lower()
                if want_period == "annual":
                    if p in annual_tags:
                        return True
                else:  # quarter
                    if p == "quarter" or p.startswith("q"):
                        return True
    except Exception:
        return False
    return False

def detect_status_for_symbol(sym: str) -> Dict[str, bool]:
    status = {k: False for k in STATUS_COLS}
    inc_path = SUBDIRS["income_statement"] / f"{sym}.jsonl"
    status["inc_FY"] = jsonl_has_period(inc_path, "annual")
    status["inc_Q"]  = jsonl_has_period(inc_path, "quarter")

    bs_path = SUBDIRS["balance_sheet"] / f"{sym}.jsonl"
    status["bs_FY"] = jsonl_has_period(bs_path, "annual")
    status["bs_Q"]  = jsonl_has_period(bs_path, "quarter")

    cf_path = SUBDIRS["cash_flow"] / f"{sym}.jsonl"
    status["cf_FY"] = jsonl_has_period(cf_path, "annual")
    status["cf_Q"]  = jsonl_has_period(cf_path, "quarter")

    ratios_path = SUBDIRS["ratios"] / f"{sym}.jsonl"
    status["ratios"] = file_has_any_rows(ratios_path)
    return status

def print_status_table(status_map: Dict[str, Dict[str, bool]], limit: int = 40):
    cols = ["ticker"] + STATUS_COLS + ["missing"]
    header = " | ".join(f"{c:>8s}" for c in cols)
    print("\n=== STATUS (first {} tickers) ===".format(limit))
    print(header)
    print("-" * len(header))
    count = 0
    for sym, st in status_map.items():
        missing = sum(1 for v in st.values() if not v)
        row = [sym] + [("✔" if st[c] else "·") for c in STATUS_COLS] + [str(missing)]
        print(" | ".join(f"{c:>8s}" for c in row))
        count += 1
        if count >= limit:
            break
    total_syms = len(status_map)
    total_missing = sum(sum(1 for v in st.values() if not v) for st in status_map.values())
    print(f"\n[summary] symbols: {total_syms} | total missing endpoints: {total_missing}\n")

def missing_count(st: Dict[str, bool]) -> int:
    return sum(1 for v in st.values() if not v)

def plan_jobs(status_map: Dict[str, Dict[str, bool]]) -> List[Tuple[str, str]]:
    tickers = list(status_map.keys())
    needers = [sym for sym in tickers if missing_count(status_map[sym]) > 0]
    needers.sort(key=lambda s: (missing_count(status_map[s]), s))
    if "AON" in needers:
        needers.remove("AON")
        needers.insert(0, "AON")

    jobs: List[Tuple[str, str]] = []
    for sym in needers:
        st = status_map[sym]
        for label in STATUS_COLS:
            if not st[label]:
                jobs.append((sym, label))
    return jobs

# ---------------- Run planner ----------------
ensure_dirs()
TICKERS: List[str] = get_all_tickers_from_duckdb()
print(f"[info] total dim_ticker symbols: {len(TICKERS)}")

STATUS_MAP: Dict[str, Dict[str, bool]] = {sym: detect_status_for_symbol(sym) for sym in TICKERS}
print_status_table(STATUS_MAP, limit=STATUS_LIMIT)

PLANNED_JOBS: List[Tuple[str, str]] = plan_jobs(STATUS_MAP)

print("=== PLANNED JOBS (preview) ===")
if not PLANNED_JOBS:
    print("(no pending jobs — everything appears present)")
else:
    for i, (sym, label) in enumerate(PLANNED_JOBS[:PREVIEW], 1):
        scope = "annual" if label.endswith("_FY") else ("quarter" if label.endswith("_Q") else "all")
        print(f"{i:2d}. {sym:<8s} → {label:<7s} ({scope})")
    if len(PLANNED_JOBS) > PREVIEW:
        print(f"... and {len(PLANNED_JOBS) - PREVIEW} more")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[14], line 149
#     147 # ---------------- Run planner ----------------
#     148 ensure_dirs()
# --> 149 TICKERS: List[str] = get_all_tickers_from_duckdb()
#     150 print(f"[info] total dim_ticker symbols: {len(TICKERS)}")
#     152 STATUS_MAP: Dict[str, Dict[str, bool]] = {sym: detect_status_for_symbol(sym) for sym in TICKERS}
#
# Cell In[14], line 48, in get_all_tickers_from_duckdb()
#      47 def get_all_tickers_from_duckdb() -> List[str]:
# ---> 48     con = duckdb.connect(DB_PATH, read_only=True)
#      49     rows = con.execute("SELECT ticker FROM dim_ticker ORDER BY ticker;").fetchall()
#      50     return [r[0] for r in rows]
#
# IOException: IO Error: Could not set lock on file "/Users/martingobbo/stock-dashboard/data/serving/analytics.duckdb": Conflicting lock is held in /usr/local/bin/node (PID 16999) by user martingobbo. See also https://duckdb.org/docs/stable/connect/concurrency

# %%
# === Cell 2: Downloader (executes the planned jobs, respects budget) ===
#!/usr/bin/env python3
"""
Consumes PLANNED_JOBS from Cell 1 and downloads ONLY missing endpoints, within a hard budget.
Re-checks disk presence before each call; appends JSONL rows.
"""

from pathlib import Path
from typing import Dict, List, Tuple
import json, time, requests

# ---- Runtime knobs ----
BUDGET = 300     # max API attempts this cell will make
SLEEP  = 1.0     # seconds between successful attempts

# ---- Helpers that rely on Cell 1 symbols (SUBDIRS, ENDPOINTS, STATUS_COLS, jsonl_has_period, file_has_any_rows) ----
def append_jsonl(path: Path, rows: List[dict]):
    if not rows:
        return
    with path.open("a") as f:
        for row in rows:
            f.write(json.dumps(row) + "\n")

def get_json(url: str, params: Dict[str, str], session: requests.Session) -> Tuple[int, List[dict]]:
    q = dict(params or {})
    q["apikey"] = API_KEY
    try:
        r = session.get(url, params=q, timeout=30)
    except Exception:
        return (-1, [])
    code = r.status_code
    if code == 200:
        try:
            data = r.json()
            if not isinstance(data, list):
                data = []
        except Exception:
            data = []
        return (200, data)
    return (code, [])

def label_to_endpoint_idx(label: str) -> int:
    return STATUS_COLS.index(label)

def is_job_already_satisfied(sym: str, label: str) -> bool:
    if label == "ratios":
        path = SUBDIRS["ratios"] / f"{sym}.jsonl"
        return file_has_any_rows(path)
    if label.startswith("inc_"):
        path = SUBDIRS["income_statement"] / f"{sym}.jsonl"
    elif label.startswith("bs_"):
        path = SUBDIRS["balance_sheet"] / f"{sym}.jsonl"
    elif label.startswith("cf_"):
        path = SUBDIRS["cash_flow"] / f"{sym}.jsonl"
    else:
        return False
    want = "annual" if label.endswith("FY") else "quarter"
    return jsonl_has_period(path, want)

def run_job(sym: str, label: str, session: requests.Session) -> Tuple[bool, int]:
    idx = label_to_endpoint_idx(label)
    subdir, tmpl, params = ENDPOINTS[idx]
    url = tmpl.format(sym=sym)
    status_code, data = get_json(url, params, session)
    if status_code == 200:
        out_path = SUBDIRS[subdir] / f"{sym}.jsonl"
        before_present = is_job_already_satisfied(sym, label)
        append_jsonl(out_path, data)
        now_present = is_job_already_satisfied(sym, label)
        got = len(data)
        if now_present and not before_present:
            print(f"[ok] {sym:6s} {label:7s} → +{got:3d} rows → {out_path}")
        else:
            print(f"[ok] {sym:6s} {label:7s} → +{got:3d} rows (no new presence) → {out_path}")
        return (True, got)
    else:
        print(f"[warn] {sym} {label} HTTP {status_code} (attempt counted)")
        return (False, 0)

# ---- Execute plan ----
if "PLANNED_JOBS" not in globals():
    raise RuntimeError("PLANNED_JOBS not found. Run Cell 1 first.")

calls_left = BUDGET
jobs_done = 0
total_rows = 0

if calls_left <= 0 or not PLANNED_JOBS:
    print("\n[stop] nothing to do (no budget or no planned jobs)\n")
else:
    with requests.Session() as s:
        for (sym, label) in PLANNED_JOBS:
            if calls_left <= 0:
                print("[stop] budget exhausted before next job")
                break

            # Skip if already satisfied (double-check disk)
            if is_job_already_satisfied(sym, label):
                if "STATUS_MAP" in globals():
                    STATUS_MAP[sym][label] = True
                continue

            success, got = run_job(sym, label, s)
            calls_left -= 1
            jobs_done += 1
            total_rows += got

            if success and "STATUS_MAP" in globals() and is_job_already_satisfied(sym, label):
                STATUS_MAP[sym][label] = True

            if calls_left <= 0:
                print("[stop] budget exhausted after this job")
                break

            if SLEEP > 0:
                time.sleep(SLEEP)

    remaining_missing = None
    if "STATUS_MAP" in globals():
        remaining_missing = sum(sum(1 for v in st.values() if not v) for st in STATUS_MAP.values())

    print(f"\n[done] jobs attempted: {jobs_done} | rows appended: {total_rows} | calls remaining: {calls_left}")
    if remaining_missing is not None:
        print(f"[after] total missing endpoints across universe: {remaining_missing}\n")
# Out:
# [ok] BRK.B  ratios  → +  0 rows (no new presence) → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/BRK.B.jsonl
# [ok] KLAC   inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KLAC.jsonl
# [ok] KLAC   bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KLAC.jsonl
# [ok] KLAC   bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KLAC.jsonl
# [ok] KLAC   cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KLAC.jsonl
# [ok] KLAC   cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KLAC.jsonl
# [ok] KLAC   ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/KLAC.jsonl
# [ok] BF.B   inc_FY  → +  0 rows (no new presence) → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/BF.B.jsonl
# [ok] BF.B   inc_Q   → +  0 rows (no new presence) → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/BF.B.jsonl
# [ok] BF.B   bs_FY   → +  0 rows (no new presence) → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/BF.B.jsonl
# [ok] BF.B   bs_Q    → +  0 rows (no new presence) → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/BF.B.jsonl
# [ok] BF.B   cf_FY   → +  0 rows (no new presence) → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/BF.B.jsonl
# [ok] BF.B   cf_Q    → +  0 rows (no new presence) → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/BF.B.jsonl
# [ok] BF.B   ratios  → +  0 rows (no new presence) → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/BF.B.jsonl
# [ok] KMB    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KMB.jsonl
# [ok] KMB    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KMB.jsonl
# [ok] KMB    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KMB.jsonl
# [ok] KMB    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KMB.jsonl
# [ok] KMB    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KMB.jsonl
# [ok] KMB    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KMB.jsonl
# [ok] KMB    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/KMB.jsonl
# [ok] KMI    inc_FY  → + 17 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KMI.jsonl
# [ok] KMI    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KMI.jsonl
# [ok] KMI    bs_FY   → + 16 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KMI.jsonl
# [ok] KMI    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KMI.jsonl
# [ok] KMI    cf_FY   → + 16 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KMI.jsonl
# [ok] KMI    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KMI.jsonl
# [ok] KMI    ratios  → + 17 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/KMI.jsonl
# [ok] KMX    inc_FY  → + 29 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KMX.jsonl
# [ok] KMX    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KMX.jsonl
# [ok] KMX    bs_FY   → + 29 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KMX.jsonl
# [ok] KMX    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KMX.jsonl
# [ok] KMX    cf_FY   → + 29 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KMX.jsonl
# [ok] KMX    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KMX.jsonl
# [ok] KMX    ratios  → + 29 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/KMX.jsonl
# [ok] KR     inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KR.jsonl
# [ok] KR     inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KR.jsonl
# [ok] KR     bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KR.jsonl
# [ok] KR     bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KR.jsonl
# [ok] KR     cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KR.jsonl
# [ok] KR     cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KR.jsonl
# [ok] KR     ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/KR.jsonl
# [ok] KVUE   inc_FY  → +  6 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KVUE.jsonl
# [ok] KVUE   inc_Q   → + 15 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/KVUE.jsonl
# [ok] KVUE   bs_FY   → +  5 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KVUE.jsonl
# [ok] KVUE   bs_Q    → + 13 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/KVUE.jsonl
# [ok] KVUE   cf_FY   → +  6 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KVUE.jsonl
# [ok] KVUE   cf_Q    → + 15 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/KVUE.jsonl
# [ok] KVUE   ratios  → +  6 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/KVUE.jsonl
# [ok] L      inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/L.jsonl
# [ok] L      inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/L.jsonl
# [ok] L      bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/L.jsonl
# [ok] L      bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/L.jsonl
# [ok] L      cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/L.jsonl
# [ok] L      cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/L.jsonl
# [ok] L      ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/L.jsonl
# [ok] LDOS   inc_FY  → + 23 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LDOS.jsonl
# [ok] LDOS   inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LDOS.jsonl
# [ok] LDOS   bs_FY   → + 23 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LDOS.jsonl
# [ok] LDOS   bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LDOS.jsonl
# [ok] LDOS   cf_FY   → + 20 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LDOS.jsonl
# [ok] LDOS   cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LDOS.jsonl
# [ok] LDOS   ratios  → + 23 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LDOS.jsonl
# [ok] LEN    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LEN.jsonl
# [ok] LEN    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LEN.jsonl
# [ok] LEN    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LEN.jsonl
# [ok] LEN    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LEN.jsonl
# [ok] LEN    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LEN.jsonl
# [ok] LEN    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LEN.jsonl
# [ok] LEN    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LEN.jsonl
# [ok] LH     inc_FY  → + 37 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LH.jsonl
# [ok] LH     inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LH.jsonl
# [ok] LH     bs_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LH.jsonl
# [ok] LH     bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LH.jsonl
# [ok] LH     cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LH.jsonl
# [ok] LH     cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LH.jsonl
# [ok] LH     ratios  → + 37 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LH.jsonl
# [ok] LHX    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LHX.jsonl
# [ok] LHX    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LHX.jsonl
# [ok] LHX    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LHX.jsonl
# [ok] LHX    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LHX.jsonl
# [ok] LHX    cf_FY   → + 37 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LHX.jsonl
# [ok] LHX    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LHX.jsonl
# [ok] LHX    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LHX.jsonl
# [ok] LII    inc_FY  → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LII.jsonl
# [ok] LII    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LII.jsonl
# [ok] LII    bs_FY   → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LII.jsonl
# [ok] LII    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LII.jsonl
# [ok] LII    cf_FY   → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LII.jsonl
# [ok] LII    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LII.jsonl
# [ok] LII    ratios  → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LII.jsonl
# [ok] LKQ    inc_FY  → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LKQ.jsonl
# [ok] LKQ    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LKQ.jsonl
# [ok] LKQ    bs_FY   → + 25 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LKQ.jsonl
# [ok] LKQ    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LKQ.jsonl
# [ok] LKQ    cf_FY   → + 25 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LKQ.jsonl
# [ok] LKQ    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LKQ.jsonl
# [ok] LKQ    ratios  → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LKQ.jsonl
# [ok] LMT    inc_FY  → + 33 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LMT.jsonl
# [ok] LMT    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LMT.jsonl
# [ok] LMT    bs_FY   → + 32 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LMT.jsonl
# [ok] LMT    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LMT.jsonl
# [ok] LMT    cf_FY   → + 33 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LMT.jsonl
# [ok] LMT    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LMT.jsonl
# [ok] LMT    ratios  → + 33 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LMT.jsonl
# [ok] LNT    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LNT.jsonl
# [ok] LNT    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LNT.jsonl
# [ok] LNT    bs_FY   → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LNT.jsonl
# [ok] LNT    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LNT.jsonl
# [ok] LNT    cf_FY   → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LNT.jsonl
# [ok] LNT    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LNT.jsonl
# [ok] LNT    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LNT.jsonl
# [ok] LOW    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LOW.jsonl
# [ok] LOW    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LOW.jsonl
# [ok] LOW    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LOW.jsonl
# [ok] LOW    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LOW.jsonl
# [ok] LOW    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LOW.jsonl
# [ok] LOW    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LOW.jsonl
# [ok] LOW    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LOW.jsonl
# [ok] LRCX   inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LRCX.jsonl
# [ok] LRCX   inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LRCX.jsonl
# [ok] LRCX   bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LRCX.jsonl
# [ok] LRCX   bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LRCX.jsonl
# [ok] LRCX   cf_FY   → + 37 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LRCX.jsonl
# [ok] LRCX   cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LRCX.jsonl
# [ok] LRCX   ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LRCX.jsonl
# [ok] LULU   inc_FY  → + 22 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LULU.jsonl
# [ok] LULU   inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LULU.jsonl
# [ok] LULU   bs_FY   → + 21 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LULU.jsonl
# [ok] LULU   bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LULU.jsonl
# [ok] LULU   cf_FY   → + 20 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LULU.jsonl
# [ok] LULU   cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LULU.jsonl
# [ok] LULU   ratios  → + 22 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LULU.jsonl
# [ok] LUV    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LUV.jsonl
# [ok] LUV    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LUV.jsonl
# [ok] LUV    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LUV.jsonl
# [ok] LUV    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LUV.jsonl
# [ok] LUV    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LUV.jsonl
# [ok] LUV    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LUV.jsonl
# [ok] LUV    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LUV.jsonl
# [ok] LVS    inc_FY  → + 25 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LVS.jsonl
# [ok] LVS    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LVS.jsonl
# [ok] LVS    bs_FY   → + 25 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LVS.jsonl
# [ok] LVS    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LVS.jsonl
# [ok] LVS    cf_FY   → + 25 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LVS.jsonl
# [ok] LVS    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LVS.jsonl
# [ok] LVS    ratios  → + 25 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LVS.jsonl
# [ok] LW     inc_FY  → + 13 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LW.jsonl
# [ok] LW     inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LW.jsonl
# [ok] LW     bs_FY   → + 12 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LW.jsonl
# [ok] LW     bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LW.jsonl
# [ok] LW     cf_FY   → + 13 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LW.jsonl
# [ok] LW     cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LW.jsonl
# [ok] LW     ratios  → + 13 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LW.jsonl
# [ok] LYB    inc_FY  → + 18 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LYB.jsonl
# [ok] LYB    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LYB.jsonl
# [ok] LYB    bs_FY   → + 17 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LYB.jsonl
# [ok] LYB    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LYB.jsonl
# [ok] LYB    cf_FY   → + 18 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LYB.jsonl
# [ok] LYB    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LYB.jsonl
# [ok] LYB    ratios  → + 18 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LYB.jsonl
# [ok] LYV    inc_FY  → + 24 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LYV.jsonl
# [ok] LYV    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/LYV.jsonl
# [ok] LYV    bs_FY   → + 24 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LYV.jsonl
# [ok] LYV    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/LYV.jsonl
# [ok] LYV    cf_FY   → + 22 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LYV.jsonl
# [ok] LYV    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/LYV.jsonl
# [ok] LYV    ratios  → + 24 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/LYV.jsonl
# [ok] MAA    inc_FY  → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MAA.jsonl
# [ok] MAA    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MAA.jsonl
# [ok] MAA    bs_FY   → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MAA.jsonl
# [ok] MAA    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MAA.jsonl
# [ok] MAA    cf_FY   → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MAA.jsonl
# [ok] MAA    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MAA.jsonl
# [ok] MAA    ratios  → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MAA.jsonl
# [ok] MAR    inc_FY  → + 28 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MAR.jsonl
# [ok] MAR    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MAR.jsonl
# [ok] MAR    bs_FY   → + 28 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MAR.jsonl
# [ok] MAR    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MAR.jsonl
# [ok] MAR    cf_FY   → + 28 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MAR.jsonl
# [ok] MAR    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MAR.jsonl
# [ok] MAR    ratios  → + 28 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MAR.jsonl
# [ok] MAS    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MAS.jsonl
# [ok] MAS    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MAS.jsonl
# [ok] MAS    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MAS.jsonl
# [ok] MAS    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MAS.jsonl
# [ok] MAS    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MAS.jsonl
# [ok] MAS    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MAS.jsonl
# [ok] MAS    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MAS.jsonl
# [ok] MCHP   inc_FY  → + 33 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MCHP.jsonl
# [ok] MCHP   inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MCHP.jsonl
# [ok] MCHP   bs_FY   → + 33 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MCHP.jsonl
# [ok] MCHP   bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MCHP.jsonl
# [ok] MCHP   cf_FY   → + 33 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MCHP.jsonl
# [ok] MCHP   cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MCHP.jsonl
# [ok] MCHP   ratios  → + 33 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MCHP.jsonl
# [ok] MCK    inc_FY  → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MCK.jsonl
# [ok] MCK    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MCK.jsonl
# [ok] MCK    bs_FY   → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MCK.jsonl
# [ok] MCK    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MCK.jsonl
# [ok] MCK    cf_FY   → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MCK.jsonl
# [ok] MCK    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MCK.jsonl
# [ok] MCK    ratios  → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MCK.jsonl
# [ok] MCO    inc_FY  → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MCO.jsonl
# [ok] MCO    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MCO.jsonl
# [ok] MCO    bs_FY   → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MCO.jsonl
# [ok] MCO    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MCO.jsonl
# [ok] MCO    cf_FY   → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MCO.jsonl
# [ok] MCO    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MCO.jsonl
# [ok] MCO    ratios  → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MCO.jsonl
# [ok] MDLZ   inc_FY  → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MDLZ.jsonl
# [ok] MDLZ   inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MDLZ.jsonl
# [ok] MDLZ   bs_FY   → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MDLZ.jsonl
# [ok] MDLZ   bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MDLZ.jsonl
# [ok] MDLZ   cf_FY   → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MDLZ.jsonl
# [ok] MDLZ   cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MDLZ.jsonl
# [ok] MDLZ   ratios  → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MDLZ.jsonl
# [ok] MDT    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MDT.jsonl
# [ok] MDT    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MDT.jsonl
# [ok] MDT    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MDT.jsonl
# [ok] MDT    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MDT.jsonl
# [ok] MDT    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MDT.jsonl
# [ok] MDT    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MDT.jsonl
# [ok] MDT    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MDT.jsonl
# [ok] MET    inc_FY  → + 30 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MET.jsonl
# [ok] MET    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MET.jsonl
# [ok] MET    bs_FY   → + 27 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MET.jsonl
# [ok] MET    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MET.jsonl
# [ok] MET    cf_FY   → + 28 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MET.jsonl
# [ok] MET    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MET.jsonl
# [ok] MET    ratios  → + 30 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MET.jsonl
# [ok] MGM    inc_FY  → + 37 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MGM.jsonl
# [ok] MGM    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MGM.jsonl
# [ok] MGM    bs_FY   → + 37 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MGM.jsonl
# [ok] MGM    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MGM.jsonl
# [ok] MGM    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MGM.jsonl
# [ok] MGM    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MGM.jsonl
# [ok] MGM    ratios  → + 37 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MGM.jsonl
# [ok] MHK    inc_FY  → + 34 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MHK.jsonl
# [ok] MHK    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MHK.jsonl
# [ok] MHK    bs_FY   → + 34 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MHK.jsonl
# [ok] MHK    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MHK.jsonl
# [ok] MHK    cf_FY   → + 34 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MHK.jsonl
# [ok] MHK    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MHK.jsonl
# [ok] MHK    ratios  → + 34 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MHK.jsonl
# [ok] MKC    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MKC.jsonl
# [ok] MKC    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MKC.jsonl
# [ok] MKC    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MKC.jsonl
# [ok] MKC    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MKC.jsonl
# [ok] MKC    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MKC.jsonl
# [ok] MKC    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MKC.jsonl
# [ok] MKC    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MKC.jsonl
# [ok] MKTX   inc_FY  → + 24 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MKTX.jsonl
# [ok] MKTX   inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MKTX.jsonl
# [ok] MKTX   bs_FY   → + 24 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MKTX.jsonl
# [ok] MKTX   bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MKTX.jsonl
# [ok] MKTX   cf_FY   → + 23 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MKTX.jsonl
# [ok] MKTX   cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MKTX.jsonl
# [ok] MKTX   ratios  → + 24 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MKTX.jsonl
# [ok] MLM    inc_FY  → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MLM.jsonl
# [ok] MLM    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MLM.jsonl
# [ok] MLM    bs_FY   → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MLM.jsonl
# [ok] MLM    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MLM.jsonl
# [ok] MLM    cf_FY   → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MLM.jsonl
# [ok] MLM    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MLM.jsonl
# [ok] MLM    ratios  → + 31 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MLM.jsonl
# [ok] MMC    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MMC.jsonl
# [ok] MMC    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MMC.jsonl
# [ok] MMC    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MMC.jsonl
# [ok] MMC    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MMC.jsonl
# [ok] MMC    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MMC.jsonl
# [ok] MMC    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MMC.jsonl
# [ok] MMC    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MMC.jsonl
# [ok] MMM    inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MMM.jsonl
# [ok] MMM    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MMM.jsonl
# [ok] MMM    bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MMM.jsonl
# [ok] MMM    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MMM.jsonl
# [ok] MMM    cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MMM.jsonl
# [ok] MMM    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MMM.jsonl
# [ok] MMM    ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MMM.jsonl
# [ok] MNST   inc_FY  → + 35 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MNST.jsonl
# [ok] MNST   inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MNST.jsonl
# [ok] MNST   bs_FY   → + 35 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MNST.jsonl
# [ok] MNST   bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MNST.jsonl
# [ok] MNST   cf_FY   → + 35 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MNST.jsonl
# [ok] MNST   cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MNST.jsonl
# [ok] MNST   ratios  → + 35 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MNST.jsonl
# [ok] MO     inc_FY  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MO.jsonl
# [ok] MO     inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MO.jsonl
# [ok] MO     bs_FY   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MO.jsonl
# [ok] MO     bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MO.jsonl
# [ok] MO     cf_FY   → + 36 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MO.jsonl
# [ok] MO     cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MO.jsonl
# [ok] MO     ratios  → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/ratios/MO.jsonl
# [ok] MOH    inc_FY  → + 26 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MOH.jsonl
# [ok] MOH    inc_Q   → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/income_statement/MOH.jsonl
# [ok] MOH    bs_FY   → + 26 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MOH.jsonl
# [ok] MOH    bs_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/balance_sheet/MOH.jsonl
# [ok] MOH    cf_FY   → + 23 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MOH.jsonl
# [ok] MOH    cf_Q    → + 40 rows → /Users/martingobbo/stock-dashboard/data/raw/fmp/cash_flow/MOH.jsonl
# [stop] budget exhausted after this job
#
# [done] jobs attempted: 300 | rows appended: 10131 | calls remaining: 0
# [after] total missing endpoints across universe: 1185
